# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/2_Advanced/05_Pandas_Index_Management.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Pandas Index Management

# %% [markdown]
# Load data.

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %% [markdown]
# ## Index Attributes
#
# ### Notes
#
# * You can get or set properties of the index, such as its name or data type.
# * It's helpful for maintaining metadata or ensuring index compatibility in operations.
# * `(index.name, index.dtype)`
#     * `index.name` - name of the index
#     * `index.dtype` - data type of the index

# %% [markdown]
# Let's look at our DataFrame.

# %%
df.sample(3)
# Out:
#               job_title_short  \
# 634145         Data Scientist
# 312061           Data Analyst
# 41578   Senior Data Scientist
#
#                                                 job_title  \
# 634145                                     Data Scientist
# 312061  Intern - (Phenomic Data Analyst for Predictive...
# 41578            SrDirector Checkout Product Data Science
#
#                     job_location           job_via job_schedule_type  \
# 634145  Gurugram, Haryana, India      via LinkedIn         Full-time
# 312061                  Anywhere      via LinkedIn        Internship
# 41578             California, MD  via ZipRecruiter         Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 634145               False           India 2023-04-13 12:17:02
# 312061                True     Netherlands 2023-08-15 17:34:58
# 41578                False         Georgia 2023-03-04 06:54:10
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 634145                  False                 False          India
# 312061                  False                 False    Netherlands
# 41578                   False                  True  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 634145        None              NaN              NaN
# 312061        None              NaN              NaN
# 41578         None              NaN              NaN
#
#                                 company_name  \
# 634145  Witzeal Technologies Private Limited
# 312061                              Syngenta
# 41578                                 PayPal
#
#                                                job_skills  \
# 634145  ['r', 'python', 'sql', 'mysql', 'hadoop', 'spa...
# 312061                           ['r', 'julia', 'python']
# 41578                                                None
#
#                                           job_type_skills
# 634145  {'databases': ['mysql'], 'libraries': ['hadoop...
# 312061          {'programming': ['r', 'julia', 'python']}
# 41578                                                None

# %% [markdown]
# Let's inspect our index.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# Our index is a range of numbers, inspecting the name...

# %%
df.index.name

# %% [markdown]
# It has no name... so let's name it.

# %%
df.index.name = 'job_index'

# %% [markdown]
# Inspecting it.

# %%
df.index.name
# Out:
# 'job_index'

# %%
df.sample(3)
# Out:
#           job_title_short                      job_title    job_location  \
# job_index
# 26399       Data Engineer              GCP Data Engineer      London, UK
# 220252     Data Scientist                 Data Scientist  Huntsville, AL
# 675368     Data Scientist  Sr Data Scientist AI Engineer      Vienna, VA
#
#                          job_via job_schedule_type  job_work_from_home  \
# job_index
# 26399      via My Stateline Jobs        Contractor               False
# 220252          via ZipRecruiter         Full-time               False
# 675368                 via BeBee         Full-time               False
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 26399               United Kingdom 2023-06-23 13:30:54                  False
# 220252      Florida, United States 2023-06-09 22:04:38                  False
# 675368     New York, United States 2023-10-27 10:02:25                  False
#
#            job_health_insurance     job_country salary_rate  salary_year_avg  \
# job_index
# 26399                     False  United Kingdom        None              NaN
# 220252                     True   United States        year          94500.0
# 675368                    False   United States        None              NaN
#
#            salary_hour_avg     company_name  \
# job_index
# 26399                  NaN          GBV Ltd
# 220252                 NaN  Nou Systems Inc
# 675368                 NaN          Idexcel
#
#                                                   job_skills  \
# job_index
# 26399      ['python', 'go', 'gcp', 'kafka', 'spark', 'pan...
# 220252       ['python', 'matlab', 'c++', 'c#', 'powerpoint']
# 675368                                             ['azure']
#
#                                              job_type_skills
# job_index
# 26399      {'cloud': ['gcp'], 'libraries': ['kafka', 'spa...
# 220252     {'analyst_tools': ['powerpoint'], 'programming...
# 675368                                  {'cloud': ['azure']}

# %% [markdown]
# ### Example 2
#
#  Remember the pivot table we made in the last example? Where we got median yearly salaries for the different job titles. Let's run that code. Then we'll get the index name and the data type of the index using `df.index.name` and `df.index.dtype`.

# %%
median_pivot = df.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc='median')
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
index_name = median_pivot.index.name
index_name
# Out:
# 'job_title_short'

# %%
index_dtype = median_pivot.index.dtype
index_dtype
# Out:
# dtype('O')

# %% [markdown]
# ## reset_index()
#
# ### Notes
#
# * `reset_index()`: Resets the DataFrame’s index to the default integer index. This is particularly useful after operations that alter the index, like sorting or filtering, to simplify further data manipulation.

# %% [markdown]
# ### Example 1
#
# When we create new DataFrames by filtering this jacks up our index!

# %%
df_usa = df[df['job_country'] == 'United States']

df_usa.head(5)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# 5           via ZipRecruiter  Contractor and Temp work                True
# 6               via LinkedIn                 Full-time               False
# 9           via ZipRecruiter                 Full-time                True
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0             Texas, United States 2023-06-16 13:44:15                  False
# 3             Texas, United States 2023-07-04 13:01:41                   True
# 5                          Georgia 2023-11-07 14:01:59                  False
# 6           Florida, United States 2023-03-27 13:18:18                  False
# 9          New York, United States 2023-04-23 13:02:57                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False  United States        None              NaN
# 3                         False  United States        None              NaN
# 5                         False  United States        None              NaN
# 6                         False  United States        None              NaN
# 9                         False  United States        None              NaN
#
#            salary_hour_avg                   company_name  \
# job_index
# 0                      NaN           Boehringer Ingelheim
# 3                      NaN   Southwest Research Institute
# 5                      NaN                smart folks inc
# 6                      NaN  Miracle Software Systems, Inc
# 9                      NaN     Radwell International, LLC
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
df_usa.index
# Out:
# Index([     0,      3,      5,      6,      9,     11,     13,     17,     26,
#            27,
#        ...
#        785625, 785626, 785641, 785648, 785651, 785673, 785685, 785692, 785703,
#        785705],
#       dtype='int64', name='job_index', length=206292)

# %% [markdown]
# Index is no longer correctly spaced by 1 increment.

# %%
df_usa.reset_index(inplace=True)
df_usa.head()
# Out:
#    job_index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 2                                  GCP Data Engineer         Anywhere
# 3                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 4                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 1  via Diversity.com                 Full-time               False
# 2   via ZipRecruiter  Contractor and Temp work                True
# 3       via LinkedIn                 Full-time               False
# 4   via ZipRecruiter                 Full-time                True
#
#            search_location     job_posted_date  job_no_degree_mention  \
# 0     Texas, United States 2023-06-16 13:44:15                  False
# 1     Texas, United States 2023-07-04 13:01:41                   True
# 2                  Georgia 2023-11-07 14:01:59                  False
# 3   Florida, United States 2023-03-27 13:18:18                  False
# 4  New York, United States 2023-04-23 13:02:57                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States        None              NaN
# 1                 False  United States        None              NaN
# 2                 False  United States        None              NaN
# 3                 False  United States        None              NaN
# 4                 False  United States        None              NaN
#
#    salary_hour_avg                   company_name  \
# 0              NaN           Boehringer Ingelheim
# 1              NaN   Southwest Research Institute
# 2              NaN                smart folks inc
# 3              NaN  Miracle Software Systems, Inc
# 4              NaN     Radwell International, LLC
#
#                                           job_skills  \
# 0                                               None
# 1  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 2                           ['python', 'sql', 'gcp']
# 3  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 4  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                      job_type_skills
# 0                                               None
# 1  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2  {'cloud': ['gcp'], 'programming': ['python', '...
# 3  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 4  {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %% [markdown]
# Technically we could `.drop()` the `job_index`.
#
# BUT, if we wanted to do some sort of merge operations in the future with our original DataFrame, this provides the unique `id` to do that.

# %% [markdown]
# ### Example 2
#
# Back to our main DataFrame with our job postings in it. We're going to actually reset the indexes in the pivot table so `job_title_short` isn't the index anymore.

# %%
median_pivot.reset_index(inplace=True)
median_pivot
# Out:
#              job_title_short  salary_year_avg
# 0           Business Analyst          85000.0
# 1             Cloud Engineer          90000.0
# 2               Data Analyst          90000.0
# 3              Data Engineer         125000.0
# 4             Data Scientist         127500.0
# 5  Machine Learning Engineer         106415.0
# 6        Senior Data Analyst         111175.0
# 7       Senior Data Engineer         147500.0
# 8      Senior Data Scientist         155500.0
# 9          Software Engineer          99150.0

# %% [markdown]
# ## set_index()
#
# ### Notes
#
# * `set_index()`: Sets one or more existing columns as the index of the DataFrame. This is useful for timeseries data or when you want to index by specific attributes.

# %% [markdown]
# ### Example 1
#
# What if we wanted to go back to job_index as our main index?

# %%
df_usa.set_index('job_index', inplace=True)

df_usa.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# 5           via ZipRecruiter  Contractor and Temp work                True
# 6               via LinkedIn                 Full-time               False
# 9           via ZipRecruiter                 Full-time                True
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0             Texas, United States 2023-06-16 13:44:15                  False
# 3             Texas, United States 2023-07-04 13:01:41                   True
# 5                          Georgia 2023-11-07 14:01:59                  False
# 6           Florida, United States 2023-03-27 13:18:18                  False
# 9          New York, United States 2023-04-23 13:02:57                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False  United States        None              NaN
# 3                         False  United States        None              NaN
# 5                         False  United States        None              NaN
# 6                         False  United States        None              NaN
# 9                         False  United States        None              NaN
#
#            salary_hour_avg                   company_name  \
# job_index
# 0                      NaN           Boehringer Ingelheim
# 3                      NaN   Southwest Research Institute
# 5                      NaN                smart folks inc
# 6                      NaN  Miracle Software Systems, Inc
# 9                      NaN     Radwell International, LLC
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %% [markdown]
# ### Example 2
#
# Now that we've reset our index we can set the new index on another column like `salary_year_avg`.

# %%
median_pivot.set_index('job_title_short', inplace=True)
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %% [markdown]
# ## sort_index()
#
# ### Notes
#
# * `sort_index()`: Sorts the DataFrame by the index (row labels), either ascending or descending. This helps in quickly organizing data by the index and is often used after `set_index()`.

# %% [markdown]
# ### Example
#
# Back to our pivoted DataFrame let's sort this new index alphabetically.

# %%
median_pivot.sort_index(inplace=True)
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0
